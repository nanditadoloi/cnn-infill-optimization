# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("PAPER_INITIAL_10.csv",sep=';')
days=data["DAYS"].to_numpy()
FOPT=data["FOPT"].to_numpy()
FOPR=data["FOPR"].to_numpy()
FWPT=data["FWPT"].to_numpy()
FWCT=data["FWCT"].to_numpy()

plt.plot(days, FOPR, '-')
plt.show()

# %%
fig, ax1 = plt.subplots()
color='tab:red'
ax1.set_xlabel('time (days)')
ax1.set_ylabel('Oil Production Rate',color=color)
ax1.plot(days, FOPR, color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2=ax1.twinx()
color='tab:blue'
ax2.set_ylabel('Cummulative Oil Production',color=color)
ax2.plot(days, FOPT, color=color)
ax2.tick_params(axis='y', labelcolor=color)

# %%
fig, ax1 = plt.subplots()
color='tab:red'
ax1.set_xlabel('time (days)')
ax1.set_ylabel('Water Cut',color=color)
ax1.plot(days, FWCT, color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2=ax1.twinx()
color='tab:blue'
ax2.set_ylabel('Cummulative Water Production',color=color)
ax2.plot(days, FWPT, color=color)
ax2.tick_params(axis='y', labelcolor=color)
